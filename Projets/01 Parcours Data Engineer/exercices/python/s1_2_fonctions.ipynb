# %% [markdown]
# # Les fonctions (cours)

# %% [markdown]
# ### Rappel

# %%
def bonjour():            # def = je définis une fonction nommée "bonjour"
    return "Salut"        # return = ce que la fonction renvoie
print(bonjour())          # on l'appelle -> "Salut"
# Out:
# Salut

# %%
def saluer(prenom):              # prenom = PARAMÈTRE
    return f"Salut {prenom}"
print(saluer("Victor"))          # "Victor" = ARGUMENT
# Out:
# Salut Victor

# %%
def augmenter(salaire, taux=0.05):   # taux vaut 0.05 par défaut sinon autre valeur si on spécifie durant l'appel
    return salaire * (1 + taux)

augmenter(40000)         # 5 %  -> 42000.0
augmenter(40000, 0.10)   # 10 % -> 44000.0
# Out:
# 44000.0

# %%
def extremes(nombres):
    return min(nombres), max(nombres)   # renvoie deux valeurs (un tuple)

mini, maxi = extremes([3, 7, 2])        # on "déballe" les deux d'un coup
# mini = 2 , maxi = 7

# %%
def carre_print(n):
    print(n * n)         # affiche, mais ne renvoie rien d'utilisable

def carre_return(n):
    return n * n         # renvoie : on peut s'en servir

total = carre_return(4) + 10   # marche -> 26
total = carre_print(4) + 10    # ERREUR : print ne renvoie rien (None)
# Out:
# 16
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       5     return n * n         # renvoie : on peut s'en servir
#       7 total = carre_return(4) + 10   # marche -> 26
# ----> 8 total = carre_print(4) + 10    # ERREUR : print ne renvoie rien (None)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %% [markdown]
# # Les fonctions (Exercices)

# %%
## 1
def salaire_annuel(salaire_mensuel):
    return salaire_mensuel * 12
salaire_annuel(3500)
# Out:
# 42000

# %%
## 2
def augmenter(salaire, taux=0.05):
    return salaire * (1 + taux)

print(augmenter(3500))
print(augmenter(3800, 0.10))
# Out:
# 3675.0
# 4180.0

# %%
## 3
def prix_ttc(prix_ht, tva = 0.20):
    return prix_ht * (1+tva)
prix_ttc(100)
# Out:
# 120.0

# %%
## 4
def  extremes(nombres):
    return min(nombres), max(nombres)
mini, maxi = extremes([12, 5, 28, 9])
print(mini, maxi)
# Out:
# 5 28

# %%
## 5
## Pour pouvoir réutiliser le résultat plus tard alors qu'un print on va seulement afficher le résultat sans le récupérer.
## print = afficher du texte 
## return = renvoyer le resultat d'un fonction
